# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Parte 1 - Seu código aqui
#url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'
# O request não estava conseguindo acessar o JSON, dava timeout, apesar de que abrindo o link no meu navegador estava acessando normalmente
# Subi o JSON num respositório no meu Github:

url = 'https://raw.githubusercontent.com/RodzMoraes/curso-ebac/main/pvl-rj.json'
r = requests.get(url)
r.status_code
# Out:
# 200

# %%
# 1) Parte 2 - Seu código aqui
data_json = r.json()
print(data_json['items'])
# Out:
# [{'id_pleito': 10561, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.001228/2011-21', 'data_protocolo': '2012-04-18T03:00:00Z', 'tipo_operacao': 'Operação contratual interna (com garantia da União)', 'finalidade': 'PAC 2 - Saneamento', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 415372248.98, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '02/07/2012'}, {'id_pleito': 13634, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '19405.000041/2002-41', 'data_protocolo': '2002-06-20T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Aquisição de máquinas, equipamentos e veículos', 'tipo_credor': 'Instituição Financeira Nacional', 'credor'
# ...

# %%
# 1) Parte 3 - Seu código aqui
pd.DataFrame(data_json['items'])
# Out:
#     id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0       10561           Estado  Rio de Janeiro        33  RJ
# 1       13634           Estado  Rio de Janeiro        33  RJ
# 2        7150           Estado  Rio de Janeiro        33  RJ
# 3       13624           Estado  Rio de Janeiro        33  RJ
# 4        7085           Estado  Rio de Janeiro        33  RJ
# 5        5516           Estado  Rio de Janeiro        33  RJ
# 6       10002           Estado  Rio de Janeiro        33  RJ
# 7        8556           Estado  Rio de Janeiro        33  RJ
# 8        7080           Estado  Rio de Janeiro        33  RJ
# 9        9750           Estado  Rio de Janeiro        33  RJ
# 10      11306           Estado  Rio de Janeiro        33  RJ
# 11      10673           Estado  Rio de Janeiro        33  RJ
# 12      21388           Estado  Rio de Janeiro        33  RJ
# 13       8528           Estado  Rio de Janeiro        33  RJ
# ...

# %%
# 2) Seu código aqui
df = pd.DataFrame(data_json['items'])

status_counts = df['status'].value_counts()
print("Os três status mais frequentes são:\n")
print(status_counts.head(3))
# Out:
# Os três status mais frequentes são:
#
# Encaminhado à PGFN com manifestação técnica favorável    34
# Deferido                                                 14
# Arquivado a pedido                                        3
# Name: status, dtype: int64

# %%
# 3) Seu código aqui
df['ano_status'] = df['data_status'].str.split('/').str[-1]
df
# Out:
#     id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0       10561           Estado  Rio de Janeiro        33  RJ
# 1       13634           Estado  Rio de Janeiro        33  RJ
# 2        7150           Estado  Rio de Janeiro        33  RJ
# 3       13624           Estado  Rio de Janeiro        33  RJ
# 4        7085           Estado  Rio de Janeiro        33  RJ
# 5        5516           Estado  Rio de Janeiro        33  RJ
# 6       10002           Estado  Rio de Janeiro        33  RJ
# 7        8556           Estado  Rio de Janeiro        33  RJ
# 8        7080           Estado  Rio de Janeiro        33  RJ
# 9        9750           Estado  Rio de Janeiro        33  RJ
# 10      11306           Estado  Rio de Janeiro        33  RJ
# 11      10673           Estado  Rio de Janeiro        33  RJ
# 12      21388           Estado  Rio de Janeiro        33  RJ
# 13       8528           Estado  Rio de Janeiro        33  RJ
# ...

# %%
# 4) Seu código aqui
df['ano_status'].value_counts()
# Out:
# 2012    11
# 2009     9
# 2013     7
# 2011     6
# 2002     4
# 2016     4
# 2014     4
# 2010     3
# 2006     2
# 2008     2
# Name: ano_status, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def consulta_pvl(uf, tipo_interessado):
    url = f'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={uf}&tipo_interessado={tipo_interessado}'
    response = requests.get(url)
    response.raise_for_status()
    data_json = response.json()
    df = pd.json_normalize(data_json['items'])
    return df

resultado = consulta_pvl('SP', 'Estado')
print(resultado)

# Não consegui rodar e testar a função porque a chamada da request estava dando Timeout

# %%
# 2) Parte 1 - Seu código aqui
url = 'https://raw.githubusercontent.com/RodzMoraes/curso-ebac/main/pvl-mg.json'
r = requests.get(url)

data_json = r.json()

pd.DataFrame(data_json['items'])
# Out:
#     id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 0       13595           Estado  Minas Gerais        31  MG
# 1        9197           Estado  Minas Gerais        31  MG
# 2       13672           Estado  Minas Gerais        31  MG
# 3       13695           Estado  Minas Gerais        31  MG
# 4       20458           Estado  Minas Gerais        31  MG
# 5       13587           Estado  Minas Gerais        31  MG
# 6        7032           Estado  Minas Gerais        31  MG
# 7       11696           Estado  Minas Gerais        31  MG
# 8        7023           Estado  Minas Gerais        31  MG
# 9       10294           Estado  Minas Gerais        31  MG
# 10      27063           Estado  Minas Gerais        31  MG
# 11       6917           Estado  Minas Gerais        31  MG
# 12       7419           Estado  Minas Gerais        31  MG
# 13       8255           Estado  Minas Gerais        31  MG
# 14       5967           Estado  Minas Gerais        31  MG
# ...

# %%
# 2) Parte 2 - Seu código aqui
df = pd.DataFrame(data_json['items'])

count = df[df['status'] == 'Arquivado por decurso de prazo'].shape[0]

print(count)
# Out:
# 1

# %%
# 3) Parte 1 - Seu código aqui
url = 'https://raw.githubusercontent.com/RodzMoraes/curso-ebac/main/pvl-ba-municipios.json'
r = requests.get(url)

data_json = r.json()

pd.DataFrame(data_json['items'])
# Out:
#      id_pleito tipo_interessado         interessado  cod_ibge  uf  \
# 0        33109        Município         Teofilândia   2931509  BA
# 1        27329        Município           Pindobaçu   2924603  BA
# 2        30327        Município    Feira de Santana   2910800  BA
# 3        22302        Município             Boquira   2904100  BA
# 4        62354        Município           Jaguarari   2917706  BA
# ..         ...              ...                 ...       ...  ..
# 900      11399        Município             Valente   2933000  BA
# 901      11851        Município  Licínio de Almeida   2919405  BA
# 902      13350        Município    Feira de Santana   2910800  BA
# 903      29853        Município        Capim Grosso   2906873  BA
# 904      62490        Município            Ibirapuã   2912806  BA
#
#                   num_pvl                          status  \
# 0    PVL02.002201/2019-40               Deferido (PVL-IF)
# ...

# %%
# 3) Parte 2 - Seu código aqui
df = pd.DataFrame(data_json['items'])

#agrupado = df.groupby('interessado')['status'].sum()
#municipio_mais_deferido = agrupado.sort_values(ascending=False).index[0]

#print(municipio_mais_deferido)


df_deferidas = df[df['status'].str.contains('Deferido')]
agrupado = df_deferidas.groupby('interessado')['status'].count().sort_values(ascending=False).reset_index()
municipio_mais_deferido = agrupado.iloc[0]['interessado']
quantidade_deferido = agrupado.iloc[0]['status']

print(f"O município com mais solicitações deferidas é {municipio_mais_deferido} com {quantidade_deferido} solicitações deferidas.")
# Out:
# O município com mais solicitações deferidas é Luís Eduardo Magalhães com 14 solicitações deferidas.

# %%
# 4) Seu código aqui

url = 'https://raw.githubusercontent.com/RodzMoraes/curso-ebac/main/pvl-ba-estado.json'
r = requests.get(url)

data_json = r.json()

df = pd.DataFrame(data_json['items'])
df.to_csv('dados-bahia.csv', index=False)
